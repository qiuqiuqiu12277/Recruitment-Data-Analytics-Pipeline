# %% [markdown]
# # Recruitment Data Analytics EDA
#
# This notebook demonstrates recruitment data preprocessing, feature extraction and exploratory analysis.

# %%
import pandas as pd

# Load processed recruitment data
